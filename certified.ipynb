# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import torch
from torch import functional as F
from torch import nn
from torchvision import datasets, transforms, models
from scipy.stats import norm, binom_test
from statsmodels.stats.proportion import proportion_confint
import time
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
class SmoothingWrapper:  # Not a Module
    def __init__(self, model, sigma, batch_size=64):
        self.model = model
        self.sigma = sigma
        self.batch_size = batch_size

        
    def predict(self, x, alpha, mc_size=None):
        """ Gets prediction counts for MC
        :param x: the input [channel x height x width]
        :param alpha: the failure probability
        :param mc_size: the number of Monte Carlo samples to use
        :return: predicted class or None
        """
        counts = self.get_prediction_counts(x, mc_size)
        count1, count2 = counts.sort(descending=True)[:2]
        if binom_test(count1, count1 + count2) < alpha:
            return counts.argmax().item()
        else:
            return None
        

    def get_prediction_counts(self, x, mc_size=None):
        """ Gets prediction counts for MC
        :param x: the input [channel x height x width]
        :param mc_size: the number of Monte Carlo samples to use
        :return: counts themselves
        """
        if mc_size is None:
            mc_size = self.batch_size
        counts = None
        with torch.no_grad():
            for processed in range(0, mc_size, self.batch_size):
                sz = min(self.batch_size, mc_size - processed)
                outputs = self.model(self._get_noised_inputs(x, sz))
                add = outputs.argmax(1).bincount(minlength=outputs.shape[1])
                if counts is None:
                    counts = add
                else:
                    counts += add
        return counts
            
        
    def _get_noised_inputs(self, x, size):
        """ Gets noised inputs
        :param x: the input [channel x height x width]
        :return:[size x ch x heights x width] - samples from N(x, diag(self.sigma**2))
        """
        # x: [ch x heights x width]
        # returns [size x ch x heights x width] with size examples shifted by noise
        
        with torch.no_grad():
            x = x.expand((size, *x.shape))
            return x + torch.randn_like(x, device=x.device) * self.sigma
        
        
    def certify(self, x, n_sel, n_est, alpha):
        """ Certify radius with probability 1 - alpha
        :param x: the input [channel x height x width]
        :param n_sel: the number of Monte Carlo samples to use for selection
        :param n_est: the number of Monte Carlo samples to use for estimation
        :param alpha: the error probability
        :return: (predicted class, certified radius) or (None, None)
        """
        counts_selection = self.get_prediction_counts(x, n_sel)
        result_class = counts_selection.argmax().item()
        count_est = self.get_prediction_counts(x, n_est)[result_class].item()
        est_lo, est_hi = proportion_confint(count_est, n_est, 2 * alpha, method='beta')
        if est_lo < 0.05:
            return None, None
        else:
            return result_class, self.sigma * norm.ppf(est_lo)
        
        
    def eval(self):
        self.model.eval()
        
    def train(self):
        self.model.train()
        
    def get_training_output(self, x):
        """ Add noise to the sample for training and compute the model there
        :param x: the input sample [batch x channel x height x width]
        :return: output [batch x classes]
        """
        return self.model(x + torch.randn_like(x, device=x.device) * self.sigma)

# %%
class MnistModel(nn.Module):
    def __init__(self):
        super(MnistModel, self).__init__()
        self.resnet18 = models.resnet18(pretrained=True)
        self.resnet18.conv1 = nn.Conv2d(1, 64, 7, 2, 3, bias=False)
        self.resnet18.fc = nn.Linear(512, 10)

    def forward(self, x):
        return self.resnet18(x)

# %%
class PeriodicPrinter:
    def __init__(self, secs):
        self.secs = secs
        self.last_time = -secs

    def print(self, *args):
        cur_time = time.time()
        if self.last_time + self.secs < cur_time:
            print(*args)
            self.last_time = cur_time
            return True
        else:
            return False

# %%
class AverageCounter:
    def __init__(self):
        self.value = 0.
        self.total = 0

    def get_average(self):
        if self.total == 0:
            return float('nan')
        else:
            return self.value / self.total
    def add(self, x):
        self.total += 1
        self.value += x

    def zero(self, right_now=True):
        if right_now:
            self.total = self.value = 0

# %%
def train(loader, wrapper, criterion, optimizer, device=torch.device('cpu')):
    wrapper.train()
    loss_cnt = AverageCounter()
    printer = PeriodicPrinter(5)

    for i, (X, y) in enumerate(loader):
        loss = criterion(wrapper.get_training_output(X.to(device)), y.to(device))
        loss_cnt.add(loss.item())
        loss_cnt.zero(printer.print('{:.4f}'.format(loss_cnt.get_average())))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
device = torch.device('cuda')

# %%
mnist_train_dataset = datasets.MNIST('mnist/', download=True, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
        ]))

# %%
mnist_test_dataset = datasets.MNIST('mnist/', train=False, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
        ]))

# %%
train_loader = torch.utils.data.DataLoader(mnist_train_dataset, 256)

# %%
criterion = nn.CrossEntropyLoss()
wrapper = SmoothingWrapper(MnistModel().to(device), 1, 256)
optimizer = torch.optim.Adam(wrapper.model.parameters(), lr=1e-3)

# %%
epoch = 0
while epoch < 100:
    epoch += 1
    print(f'Epoch {epoch}')
    train(train_loader, wrapper, criterion, optimizer, device)
# Out:
# Epoch 1
# 2.6239
# 0.6684
# 0.2256
# 0.1696
# Epoch 2
# 0.1390
# 0.1219
# 0.1060
# 0.1015
# Epoch 3
# 0.1189
# 0.0891
# 0.0774
# 0.0783
# Epoch 4
# 0.1068
# 0.0661
# 0.0644
# 0.0712
# Epoch 5
# 0.0861
# 0.0576
# 0.0538
# 0.0569
# Epoch 6
# 0.0824
# 0.0529
# 0.0514
# 0.0509
# Epoch 7
# 0.0700
# 0.0485
# 0.0443
# 0.0491
# Epoch 8
# 0.0583
# 0.0438
# 0.0446
# 0.0438
# Epoch 9
# 0.0407
# 0.0378
# 0.0404
# 0.0386
# Epoch 10
# 0.0481
# 0.0348
# 0.0411
# 0.0372
# Epoch 11
# 0.0200
# 0.0361
# 0.0342
# 0.0369
# Epoch 12
# 0.0576
# 0.0341
# 0.0296
# 0.0333
# Epoch 13
# 0.0342
# 0.0336
# 0.0340
# 0.0344
# Epoch 14
# 0.0230
# 0.0326
# 0.0292
# 0.0368
# Epoch 15
# 0.0290
# 0.0295
# 0.0288
# 0.0335
# Epoch 16
# 0.0203
# 0.0304
# 0.0296
# 0.0326
# Epoch 17
# 0.0211
# 0.0251
# 0.0255
# 0.0257
# Epoch 18
# 0.0438
# 0.0221
# 0.0279
# 0.0273
# Epoch 19
# 0.0182
# 0.0246
# 0.0257
# 0.0276
# Epoch 20
# 0.0270
# 0.0266
# 0.0209
# 0.0268
# Epoch 21
# 0.0187
# 0.0224
# 0.0306
# 0.0232
# Epoch 22
# 0.0112
# 0.0237
# 0.0226
# 0.0242
# Epoch 23
# 0.0097
# 0.0237
# 0.0182
# 0.0190
# Epoch 24
# 0.0653
# 0.0204
# 0.0152
# 0.0266
# Epoch 25
# 0.0352
# 0.0201
# 0.0210
# 0.0186
# Epoch 26
# 0.0331
# 0.0194
# 0.0180
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-54a74da7f762> in <module>()
#       3     epoch += 1
#       4     print(f'Epoch {epoch}')
# ----> 5     train(train_loader, wrapper, criterion, optimizer, device)
#
# <ipython-input-7-1d226b9cc091> in train(loader, wrapper, criterion, optimizer, device)
#       5
#       6     for i, (X, y) in enumerate(loader):
# ----> 7         loss = criterion(wrapper.get_training_output(X.to(device)), y.to(device))
#       8         loss_cnt.add(loss.item())
#       9         loss_cnt.zero(printer.print('{:.4f}'.format(loss_cnt.get_average())))
#
# KeyboardInterrupt:

# %%
def test(dataset, wrapper, n, alpha, radii, device):
    wrapper.eval()
    radii = np.asarray(radii)
    accuracies = np.zeros(len(radii))
    printer = PeriodicPrinter(5)
    res = np.zeros(len(dataset))
    for i, (X, y) in enumerate(dataset):
        cl, radius = wrapper.certify(X.to(device), n, n, alpha)
        if cl == y:
            res[i] = radius
            accuracies[radii < radius] += 1
        else:
            res[i] = float('nan')
        if printer.print(f'Iteration {i + 1}'):
            for r, a in zip(radii, accuracies / (1 + i) * 100):
                 print(f'Accuracy @ {r} = {a}%')
    for r, a in zip(radii, accuracies / len(dataset)):
        print(f'Accuracy @ {r} = {a * 100}%')
    return res

# %%
res = test(mnist_test_dataset, wrapper, 10000, 0.001, [0, 1., 2.5, 3., 3.5, 4., 4.5, 5., 10.], device)
# Out:
# Iteration 1
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 100.0%
# Accuracy @ 2.5 = 100.0%
# Accuracy @ 3.0 = 100.0%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 9
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 100.0%
# Accuracy @ 2.5 = 88.88888888888889%
# Accuracy @ 3.0 = 88.88888888888889%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 17
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 100.0%
# Accuracy @ 2.5 = 94.11764705882352%
# Accuracy @ 3.0 = 94.11764705882352%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 25
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 96.0%
# Accuracy @ 2.5 = 92.0%
# Accuracy @ 3.0 = 84.0%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 33
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 96.96969696969697%
# Accuracy @ 2.5 = 93.93939393939394%
# Accuracy @ 3.0 = 87.87878787878788%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 41
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 97.5609756097561%
# Accuracy @ 2.5 = 92.6829268292683%
# Accuracy @ 3.0 = 87.8048780487805%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 49
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 97.95918367346938%
# Accuracy @ 2.5 = 93.87755102040816%
# Accuracy @ 3.0 = 87.75510204081633%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 57
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.24561403508771%
# Accuracy @ 2.5 = 94.73684210526315%
# Accuracy @ 3.0 = 89.47368421052632%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 65
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.46153846153847%
# Accuracy @ 2.5 = 93.84615384615384%
# Accuracy @ 3.0 = 89.23076923076924%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 73
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.63013698630137%
# Accuracy @ 2.5 = 94.52054794520548%
# Accuracy @ 3.0 = 89.04109589041096%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 81
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.76543209876543%
# Accuracy @ 2.5 = 95.06172839506173%
# Accuracy @ 3.0 = 88.88888888888889%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 89
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.87640449438202%
# Accuracy @ 2.5 = 95.50561797752809%
# Accuracy @ 3.0 = 89.8876404494382%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 97
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 97.9381443298969%
# Accuracy @ 2.5 = 94.84536082474226%
# Accuracy @ 3.0 = 86.5979381443299%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 105
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.09523809523809%
# Accuracy @ 2.5 = 95.23809523809523%
# Accuracy @ 3.0 = 86.66666666666667%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 113
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.23008849557522%
# Accuracy @ 2.5 = 95.57522123893806%
# Accuracy @ 3.0 = 87.61061946902655%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 121
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.34710743801654%
# Accuracy @ 2.5 = 94.21487603305785%
# Accuracy @ 3.0 = 85.9504132231405%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 129
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.44961240310077%
# Accuracy @ 2.5 = 94.57364341085271%
# Accuracy @ 3.0 = 86.82170542635659%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 137
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.54014598540147%
# Accuracy @ 2.5 = 94.8905109489051%
# Accuracy @ 3.0 = 87.59124087591242%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 145
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.62068965517241%
# Accuracy @ 2.5 = 95.17241379310344%
# Accuracy @ 3.0 = 88.27586206896552%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 153
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.69281045751634%
# Accuracy @ 2.5 = 94.11764705882352%
# Accuracy @ 3.0 = 87.58169934640523%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 161
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.75776397515527%
# Accuracy @ 2.5 = 93.7888198757764%
# Accuracy @ 3.0 = 87.5776397515528%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 169
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.81656804733728%
# Accuracy @ 2.5 = 93.49112426035504%
# Accuracy @ 3.0 = 87.57396449704143%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 177
# Accuracy @ 0.0 = 100.0%
# Accuracy @ 1.0 = 98.87005649717514%
# Accuracy @ 2.5 = 93.22033898305084%
# Accuracy @ 3.0 = 87.57062146892656%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 185
# Accuracy @ 0.0 = 99.45945945945947%
# Accuracy @ 1.0 = 98.37837837837839%
# Accuracy @ 2.5 = 92.97297297297298%
# Accuracy @ 3.0 = 87.02702702702703%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 193
# Accuracy @ 0.0 = 99.48186528497409%
# Accuracy @ 1.0 = 98.44559585492227%
# Accuracy @ 2.5 = 92.74611398963731%
# Accuracy @ 3.0 = 86.52849740932642%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 201
# Accuracy @ 0.0 = 99.50248756218906%
# Accuracy @ 1.0 = 98.50746268656717%
# Accuracy @ 2.5 = 92.53731343283582%
# Accuracy @ 3.0 = 86.06965174129353%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 209
# Accuracy @ 0.0 = 99.52153110047847%
# Accuracy @ 1.0 = 98.56459330143541%
# Accuracy @ 2.5 = 92.82296650717703%
# Accuracy @ 3.0 = 86.1244019138756%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 217
# Accuracy @ 0.0 = 99.53917050691244%
# Accuracy @ 1.0 = 98.61751152073732%
# Accuracy @ 2.5 = 93.08755760368663%
# Accuracy @ 3.0 = 86.63594470046083%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 225
# Accuracy @ 0.0 = 99.55555555555556%
# Accuracy @ 1.0 = 98.66666666666667%
# Accuracy @ 2.5 = 93.33333333333333%
# Accuracy @ 3.0 = 86.22222222222223%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 233
# Accuracy @ 0.0 = 99.57081545064378%
# Accuracy @ 1.0 = 98.71244635193133%
# Accuracy @ 2.5 = 93.56223175965665%
# Accuracy @ 3.0 = 86.69527896995707%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 241
# Accuracy @ 0.0 = 99.5850622406639%
# Accuracy @ 1.0 = 98.7551867219917%
# Accuracy @ 2.5 = 93.7759336099585%
# Accuracy @ 3.0 = 86.72199170124482%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 249
# Accuracy @ 0.0 = 99.59839357429718%
# Accuracy @ 1.0 = 98.39357429718876%
# Accuracy @ 2.5 = 93.57429718875501%
# Accuracy @ 3.0 = 86.34538152610442%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 257
# Accuracy @ 0.0 = 99.61089494163424%
# Accuracy @ 1.0 = 98.44357976653697%
# Accuracy @ 2.5 = 93.3852140077821%
# Accuracy @ 3.0 = 86.38132295719845%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 265
# Accuracy @ 0.0 = 99.62264150943396%
# Accuracy @ 1.0 = 98.49056603773585%
# Accuracy @ 2.5 = 93.20754716981132%
# Accuracy @ 3.0 = 86.41509433962264%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 273
# Accuracy @ 0.0 = 99.63369963369964%
# Accuracy @ 1.0 = 98.53479853479854%
# Accuracy @ 2.5 = 93.04029304029304%
# Accuracy @ 3.0 = 86.44688644688645%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 281
# Accuracy @ 0.0 = 99.644128113879%
# Accuracy @ 1.0 = 98.57651245551602%
# Accuracy @ 2.5 = 93.23843416370107%
# Accuracy @ 3.0 = 86.83274021352312%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 289
# Accuracy @ 0.0 = 99.65397923875432%
# Accuracy @ 1.0 = 98.6159169550173%
# Accuracy @ 2.5 = 93.42560553633218%
# Accuracy @ 3.0 = 87.19723183391004%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 297
# Accuracy @ 0.0 = 99.66329966329967%
# Accuracy @ 1.0 = 98.65319865319864%
# Accuracy @ 2.5 = 93.26599326599326%
# Accuracy @ 3.0 = 87.20538720538721%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 305
# Accuracy @ 0.0 = 99.672131147541%
# Accuracy @ 1.0 = 98.68852459016394%
# Accuracy @ 2.5 = 93.11475409836065%
# Accuracy @ 3.0 = 87.21311475409837%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 313
# Accuracy @ 0.0 = 99.68051118210862%
# Accuracy @ 1.0 = 98.7220447284345%
# Accuracy @ 2.5 = 93.29073482428115%
# Accuracy @ 3.0 = 87.53993610223642%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 321
# Accuracy @ 0.0 = 99.68847352024922%
# Accuracy @ 1.0 = 98.75389408099689%
# Accuracy @ 2.5 = 93.14641744548287%
# Accuracy @ 3.0 = 87.22741433021807%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 329
# Accuracy @ 0.0 = 99.3920972644377%
# Accuracy @ 1.0 = 98.48024316109422%
# Accuracy @ 2.5 = 92.70516717325228%
# Accuracy @ 3.0 = 86.93009118541033%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 337
# Accuracy @ 0.0 = 99.40652818991099%
# Accuracy @ 1.0 = 98.51632047477746%
# Accuracy @ 2.5 = 92.87833827893175%
# Accuracy @ 3.0 = 86.94362017804154%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 345
# Accuracy @ 0.0 = 99.42028985507247%
# Accuracy @ 1.0 = 98.26086956521739%
# Accuracy @ 2.5 = 91.88405797101449%
# Accuracy @ 3.0 = 86.08695652173914%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 353
# Accuracy @ 0.0 = 99.43342776203966%
# Accuracy @ 1.0 = 98.30028328611898%
# Accuracy @ 2.5 = 91.78470254957507%
# Accuracy @ 3.0 = 86.11898016997166%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 361
# Accuracy @ 0.0 = 99.44598337950139%
# Accuracy @ 1.0 = 98.33795013850416%
# Accuracy @ 2.5 = 91.41274238227147%
# Accuracy @ 3.0 = 85.59556786703601%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 369
# Accuracy @ 0.0 = 99.45799457994579%
# Accuracy @ 1.0 = 98.3739837398374%
# Accuracy @ 2.5 = 91.32791327913279%
# Accuracy @ 3.0 = 85.09485094850947%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 377
# Accuracy @ 0.0 = 99.46949602122017%
# Accuracy @ 1.0 = 98.40848806366049%
# Accuracy @ 2.5 = 91.51193633952255%
# Accuracy @ 3.0 = 85.14588859416446%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 385
# Accuracy @ 0.0 = 99.48051948051948%
# Accuracy @ 1.0 = 98.44155844155844%
# Accuracy @ 2.5 = 91.42857142857143%
# Accuracy @ 3.0 = 85.19480519480518%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 393
# Accuracy @ 0.0 = 99.49109414758269%
# Accuracy @ 1.0 = 98.47328244274809%
# Accuracy @ 2.5 = 91.6030534351145%
# Accuracy @ 3.0 = 85.24173027989822%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 401
# Accuracy @ 0.0 = 99.50124688279301%
# Accuracy @ 1.0 = 98.50374064837905%
# Accuracy @ 2.5 = 91.52119700748129%
# Accuracy @ 3.0 = 85.286783042394%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 409
# Accuracy @ 0.0 = 99.51100244498777%
# Accuracy @ 1.0 = 98.0440097799511%
# Accuracy @ 2.5 = 91.19804400977995%
# Accuracy @ 3.0 = 85.08557457212714%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 417
# Accuracy @ 0.0 = 99.52038369304557%
# Accuracy @ 1.0 = 98.08153477218225%
# Accuracy @ 2.5 = 91.12709832134293%
# Accuracy @ 3.0 = 84.89208633093526%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 425
# Accuracy @ 0.0 = 99.52941176470588%
# Accuracy @ 1.0 = 98.11764705882354%
# Accuracy @ 2.5 = 91.05882352941177%
# Accuracy @ 3.0 = 84.70588235294117%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 433
# Accuracy @ 0.0 = 99.53810623556582%
# Accuracy @ 1.0 = 98.15242494226328%
# Accuracy @ 2.5 = 91.22401847575058%
# Accuracy @ 3.0 = 84.98845265588915%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 441
# Accuracy @ 0.0 = 99.54648526077098%
# Accuracy @ 1.0 = 98.1859410430839%
# Accuracy @ 2.5 = 91.15646258503402%
# Accuracy @ 3.0 = 85.03401360544217%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 449
# Accuracy @ 0.0 = 99.33184855233853%
# Accuracy @ 1.0 = 97.9955456570156%
# Accuracy @ 2.5 = 90.42316258351893%
# Accuracy @ 3.0 = 84.4097995545657%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 457
# Accuracy @ 0.0 = 99.12472647702407%
# Accuracy @ 1.0 = 97.81181619256017%
# Accuracy @ 2.5 = 89.93435448577681%
# Accuracy @ 3.0 = 84.02625820568927%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 465
# Accuracy @ 0.0 = 99.13978494623656%
# Accuracy @ 1.0 = 97.84946236559139%
# Accuracy @ 2.5 = 89.89247311827957%
# Accuracy @ 3.0 = 83.87096774193549%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 473
# Accuracy @ 0.0 = 99.15433403805497%
# Accuracy @ 1.0 = 97.88583509513742%
# Accuracy @ 2.5 = 89.85200845665962%
# Accuracy @ 3.0 = 83.50951374207189%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 481
# Accuracy @ 0.0 = 99.16839916839916%
# Accuracy @ 1.0 = 97.92099792099792%
# Accuracy @ 2.5 = 90.02079002079002%
# Accuracy @ 3.0 = 83.78378378378379%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 489
# Accuracy @ 0.0 = 99.18200408997954%
# Accuracy @ 1.0 = 97.95501022494888%
# Accuracy @ 2.5 = 90.1840490797546%
# Accuracy @ 3.0 = 83.84458077709611%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 497
# Accuracy @ 0.0 = 99.19517102615694%
# Accuracy @ 1.0 = 97.78672032193158%
# Accuracy @ 2.5 = 90.14084507042254%
# Accuracy @ 3.0 = 83.90342052313883%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 505
# Accuracy @ 0.0 = 99.20792079207921%
# Accuracy @ 1.0 = 97.82178217821782%
# Accuracy @ 2.5 = 90.0990099009901%
# Accuracy @ 3.0 = 83.96039603960396%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 513
# Accuracy @ 0.0 = 99.22027290448344%
# Accuracy @ 1.0 = 97.85575048732943%
# Accuracy @ 2.5 = 90.25341130604289%
# Accuracy @ 3.0 = 83.82066276803118%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 521
# Accuracy @ 0.0 = 99.23224568138195%
# Accuracy @ 1.0 = 97.88867562380038%
# Accuracy @ 2.5 = 90.40307101727447%
# Accuracy @ 3.0 = 83.87715930902111%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 529
# Accuracy @ 0.0 = 99.24385633270322%
# Accuracy @ 1.0 = 97.92060491493385%
# Accuracy @ 2.5 = 90.54820415879017%
# Accuracy @ 3.0 = 84.12098298676749%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 537
# Accuracy @ 0.0 = 99.25512104283054%
# Accuracy @ 1.0 = 97.95158286778398%
# Accuracy @ 2.5 = 90.5027932960894%
# Accuracy @ 3.0 = 84.17132216014897%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 545
# Accuracy @ 0.0 = 99.26605504587155%
# Accuracy @ 1.0 = 97.9816513761468%
# Accuracy @ 2.5 = 90.27522935779817%
# Accuracy @ 3.0 = 84.03669724770643%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 553
# Accuracy @ 0.0 = 99.27667269439421%
# Accuracy @ 1.0 = 98.01084990958408%
# Accuracy @ 2.5 = 90.05424954792043%
# Accuracy @ 3.0 = 83.90596745027125%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 561
# Accuracy @ 0.0 = 99.28698752228165%
# Accuracy @ 1.0 = 98.0392156862745%
# Accuracy @ 2.5 = 90.19607843137256%
# Accuracy @ 3.0 = 84.13547237076648%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 569
# Accuracy @ 0.0 = 99.29701230228471%
# Accuracy @ 1.0 = 98.06678383128296%
# Accuracy @ 2.5 = 90.15817223198594%
# Accuracy @ 3.0 = 84.18277680140598%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 577
# Accuracy @ 0.0 = 99.30675909878683%
# Accuracy @ 1.0 = 98.09358752166378%
# Accuracy @ 2.5 = 90.1213171577123%
# Accuracy @ 3.0 = 84.22876949740035%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 585
# Accuracy @ 0.0 = 98.97435897435898%
# Accuracy @ 1.0 = 97.77777777777777%
# Accuracy @ 2.5 = 89.91452991452992%
# Accuracy @ 3.0 = 84.1025641025641%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 593
# Accuracy @ 0.0 = 98.98819561551433%
# Accuracy @ 1.0 = 97.63912310286678%
# Accuracy @ 2.5 = 89.88195615514334%
# Accuracy @ 3.0 = 83.97976391231029%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 601
# Accuracy @ 0.0 = 99.00166389351082%
# Accuracy @ 1.0 = 97.67054908485858%
# Accuracy @ 2.5 = 90.01663893510815%
# Accuracy @ 3.0 = 84.02662229617304%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 609
# Accuracy @ 0.0 = 99.01477832512316%
# Accuracy @ 1.0 = 97.70114942528735%
# Accuracy @ 2.5 = 89.98357963875205%
# Accuracy @ 3.0 = 84.07224958949097%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 617
# Accuracy @ 0.0 = 99.02755267423015%
# Accuracy @ 1.0 = 97.73095623987034%
# Accuracy @ 2.5 = 89.9513776337115%
# Accuracy @ 3.0 = 84.11669367909238%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 625
# Accuracy @ 0.0 = 99.03999999999999%
# Accuracy @ 1.0 = 97.76%
# Accuracy @ 2.5 = 89.92%
# Accuracy @ 3.0 = 84.16%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 633
# Accuracy @ 0.0 = 98.89415481832543%
# Accuracy @ 1.0 = 97.6303317535545%
# Accuracy @ 2.5 = 89.73143759873618%
# Accuracy @ 3.0 = 83.88625592417061%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 641
# Accuracy @ 0.0 = 98.90795631825273%
# Accuracy @ 1.0 = 97.65990639625585%
# Accuracy @ 2.5 = 89.85959438377536%
# Accuracy @ 3.0 = 83.93135725429018%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 649
# Accuracy @ 0.0 = 98.92141756548536%
# Accuracy @ 1.0 = 97.5346687211094%
# Accuracy @ 2.5 = 89.83050847457628%
# Accuracy @ 3.0 = 83.9753466872111%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 657
# Accuracy @ 0.0 = 98.93455098934551%
# Accuracy @ 1.0 = 97.56468797564688%
# Accuracy @ 2.5 = 89.95433789954338%
# Accuracy @ 3.0 = 83.86605783866058%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 665
# Accuracy @ 0.0 = 98.796992481203%
# Accuracy @ 1.0 = 97.44360902255639%
# Accuracy @ 2.5 = 89.92481203007519%
# Accuracy @ 3.0 = 83.90977443609022%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 673
# Accuracy @ 0.0 = 98.81129271916791%
# Accuracy @ 1.0 = 97.47399702823179%
# Accuracy @ 2.5 = 90.04457652303121%
# Accuracy @ 3.0 = 83.8038632986627%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 681
# Accuracy @ 0.0 = 98.82525697503671%
# Accuracy @ 1.0 = 97.3568281938326%
# Accuracy @ 2.5 = 90.01468428781205%
# Accuracy @ 3.0 = 83.84728340675477%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 689
# Accuracy @ 0.0 = 98.8388969521045%
# Accuracy @ 1.0 = 97.38751814223512%
# Accuracy @ 2.5 = 89.84034833091437%
# Accuracy @ 3.0 = 83.74455732946299%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 697
# Accuracy @ 0.0 = 98.70875179340028%
# Accuracy @ 1.0 = 97.27403156384506%
# Accuracy @ 2.5 = 89.6700143472023%
# Accuracy @ 3.0 = 83.35724533715926%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 705
# Accuracy @ 0.0 = 98.72340425531915%
# Accuracy @ 1.0 = 97.30496453900709%
# Accuracy @ 2.5 = 89.7872340425532%
# Accuracy @ 3.0 = 83.26241134751773%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 713
# Accuracy @ 0.0 = 98.73772791023842%
# Accuracy @ 1.0 = 97.3352033660589%
# Accuracy @ 2.5 = 89.76157082748948%
# Accuracy @ 3.0 = 83.16970546984572%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 721
# Accuracy @ 0.0 = 98.6130374479889%
# Accuracy @ 1.0 = 97.0873786407767%
# Accuracy @ 2.5 = 89.59778085991678%
# Accuracy @ 3.0 = 82.94036061026353%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 729
# Accuracy @ 0.0 = 98.62825788751715%
# Accuracy @ 1.0 = 97.11934156378601%
# Accuracy @ 2.5 = 89.57475994513031%
# Accuracy @ 3.0 = 82.71604938271605%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 737
# Accuracy @ 0.0 = 98.64314789687924%
# Accuracy @ 1.0 = 97.15061058344641%
# Accuracy @ 2.5 = 89.68792401628222%
# Accuracy @ 3.0 = 82.90366350067842%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 745
# Accuracy @ 0.0 = 98.65771812080537%
# Accuracy @ 1.0 = 97.0469798657718%
# Accuracy @ 2.5 = 89.66442953020135%
# Accuracy @ 3.0 = 82.81879194630872%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 753
# Accuracy @ 0.0 = 98.67197875166002%
# Accuracy @ 1.0 = 97.07835325365207%
# Accuracy @ 2.5 = 89.7742363877822%
# Accuracy @ 3.0 = 83.00132802124834%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 761
# Accuracy @ 0.0 = 98.68593955321944%
# Accuracy @ 1.0 = 97.10906701708278%
# Accuracy @ 2.5 = 89.7503285151117%
# Accuracy @ 3.0 = 83.04862023653088%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 769
# Accuracy @ 0.0 = 98.6996098829649%
# Accuracy @ 1.0 = 97.13914174252277%
# Accuracy @ 2.5 = 89.85695708712613%
# Accuracy @ 3.0 = 83.22496749024707%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 777
# Accuracy @ 0.0 = 98.71299871299871%
# Accuracy @ 1.0 = 97.16859716859717%
# Accuracy @ 2.5 = 89.83268983268984%
# Accuracy @ 3.0 = 83.26898326898326%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 785
# Accuracy @ 0.0 = 98.72611464968153%
# Accuracy @ 1.0 = 97.19745222929936%
# Accuracy @ 2.5 = 89.93630573248407%
# Accuracy @ 3.0 = 83.31210191082803%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 793
# Accuracy @ 0.0 = 98.7389659520807%
# Accuracy @ 1.0 = 97.22572509457756%
# Accuracy @ 2.5 = 90.03783102143757%
# Accuracy @ 3.0 = 83.2282471626734%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 801
# Accuracy @ 0.0 = 98.75156054931335%
# Accuracy @ 1.0 = 97.2534332084894%
# Accuracy @ 2.5 = 90.13732833957553%
# Accuracy @ 3.0 = 83.270911360799%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 809
# Accuracy @ 0.0 = 98.76390605686032%
# Accuracy @ 1.0 = 97.28059332509271%
# Accuracy @ 2.5 = 90.23485784919654%
# Accuracy @ 3.0 = 83.43634116192831%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 817
# Accuracy @ 0.0 = 98.77600979192167%
# Accuracy @ 1.0 = 97.30722154222767%
# Accuracy @ 2.5 = 90.33047735618115%
# Accuracy @ 3.0 = 83.5985312117503%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 825
# Accuracy @ 0.0 = 98.7878787878788%
# Accuracy @ 1.0 = 97.33333333333334%
# Accuracy @ 2.5 = 90.30303030303031%
# Accuracy @ 3.0 = 83.63636363636363%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 833
# Accuracy @ 0.0 = 98.79951980792316%
# Accuracy @ 1.0 = 97.35894357743096%
# Accuracy @ 2.5 = 90.39615846338536%
# Accuracy @ 3.0 = 83.79351740696278%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 841
# Accuracy @ 0.0 = 98.81093935790726%
# Accuracy @ 1.0 = 97.38406658739595%
# Accuracy @ 2.5 = 90.36860879904876%
# Accuracy @ 3.0 = 83.5909631391201%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 849
# Accuracy @ 0.0 = 98.82214369846879%
# Accuracy @ 1.0 = 97.29093050647822%
# Accuracy @ 2.5 = 90.22379269729093%
# Accuracy @ 3.0 = 83.51001177856303%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 857
# Accuracy @ 0.0 = 98.83313885647608%
# Accuracy @ 1.0 = 97.31621936989498%
# Accuracy @ 2.5 = 90.31505250875146%
# Accuracy @ 3.0 = 83.66394399066512%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 865
# Accuracy @ 0.0 = 98.84393063583815%
# Accuracy @ 1.0 = 97.34104046242774%
# Accuracy @ 2.5 = 90.40462427745665%
# Accuracy @ 3.0 = 83.8150289017341%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 873
# Accuracy @ 0.0 = 98.85452462772051%
# Accuracy @ 1.0 = 97.36540664375715%
# Accuracy @ 2.5 = 90.26345933562429%
# Accuracy @ 3.0 = 83.61970217640321%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 881
# Accuracy @ 0.0 = 98.86492622020431%
# Accuracy @ 1.0 = 97.38933030646993%
# Accuracy @ 2.5 = 90.23836549375709%
# Accuracy @ 3.0 = 83.65493757094211%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 889
# Accuracy @ 0.0 = 98.87514060742407%
# Accuracy @ 1.0 = 97.30033745781778%
# Accuracy @ 2.5 = 89.98875140607424%
# Accuracy @ 3.0 = 83.35208098987627%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 897
# Accuracy @ 0.0 = 98.88517279821627%
# Accuracy @ 1.0 = 97.32441471571906%
# Accuracy @ 2.5 = 90.07803790412487%
# Accuracy @ 3.0 = 83.5005574136009%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 905
# Accuracy @ 0.0 = 98.78453038674033%
# Accuracy @ 1.0 = 97.23756906077348%
# Accuracy @ 2.5 = 90.05524861878453%
# Accuracy @ 3.0 = 83.42541436464089%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 913
# Accuracy @ 0.0 = 98.79518072289156%
# Accuracy @ 1.0 = 97.26177437020812%
# Accuracy @ 2.5 = 90.14238773274917%
# Accuracy @ 3.0 = 83.57064622124864%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 921
# Accuracy @ 0.0 = 98.8056460369164%
# Accuracy @ 1.0 = 97.28555917480999%
# Accuracy @ 2.5 = 90.11943539630836%
# Accuracy @ 3.0 = 83.60477741585234%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 929
# Accuracy @ 0.0 = 98.70828848223897%
# Accuracy @ 1.0 = 97.20129171151775%
# Accuracy @ 2.5 = 89.98923573735199%
# Accuracy @ 3.0 = 83.53067814854683%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 937
# Accuracy @ 0.0 = 98.71931696905017%
# Accuracy @ 1.0 = 97.22518676627536%
# Accuracy @ 2.5 = 90.07470651013874%
# Accuracy @ 3.0 = 83.56456776947705%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 945
# Accuracy @ 0.0 = 98.73015873015873%
# Accuracy @ 1.0 = 97.24867724867725%
# Accuracy @ 2.5 = 90.05291005291005%
# Accuracy @ 3.0 = 83.3862433862434%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 953
# Accuracy @ 0.0 = 98.63588667366213%
# Accuracy @ 1.0 = 97.16684155299056%
# Accuracy @ 2.5 = 89.92654774396642%
# Accuracy @ 3.0 = 83.31584470094438%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 961
# Accuracy @ 0.0 = 98.64724245577523%
# Accuracy @ 1.0 = 97.1904266389178%
# Accuracy @ 2.5 = 89.69823100936524%
# Accuracy @ 3.0 = 83.0385015608741%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 969
# Accuracy @ 0.0 = 98.55521155830753%
# Accuracy @ 1.0 = 97.11042311661507%
# Accuracy @ 2.5 = 89.57688338493293%
# Accuracy @ 3.0 = 82.76573787409701%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 977
# Accuracy @ 0.0 = 98.56704196519959%
# Accuracy @ 1.0 = 97.13408393039919%
# Accuracy @ 2.5 = 89.55987717502559%
# Accuracy @ 3.0 = 82.7021494370522%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 985
# Accuracy @ 0.0 = 98.57868020304569%
# Accuracy @ 1.0 = 97.15736040609137%
# Accuracy @ 2.5 = 89.64467005076142%
# Accuracy @ 3.0 = 82.84263959390863%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 993
# Accuracy @ 0.0 = 98.5901309164149%
# Accuracy @ 1.0 = 97.1802618328298%
# Accuracy @ 2.5 = 89.72809667673715%
# Accuracy @ 3.0 = 82.88016112789526%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1001
# Accuracy @ 0.0 = 98.6013986013986%
# Accuracy @ 1.0 = 97.2027972027972%
# Accuracy @ 2.5 = 89.81018981018981%
# Accuracy @ 3.0 = 82.91708291708292%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1009
# Accuracy @ 0.0 = 98.61248761149653%
# Accuracy @ 1.0 = 97.22497522299307%
# Accuracy @ 2.5 = 89.79187314172448%
# Accuracy @ 3.0 = 82.85431119920713%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1017
# Accuracy @ 0.0 = 98.52507374631269%
# Accuracy @ 1.0 = 97.14847590953785%
# Accuracy @ 2.5 = 89.67551622418878%
# Accuracy @ 3.0 = 82.69419862340216%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1025
# Accuracy @ 0.0 = 98.53658536585365%
# Accuracy @ 1.0 = 97.17073170731707%
# Accuracy @ 2.5 = 89.65853658536585%
# Accuracy @ 3.0 = 82.6341463414634%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1033
# Accuracy @ 0.0 = 98.54791868344628%
# Accuracy @ 1.0 = 97.19264278799614%
# Accuracy @ 2.5 = 89.73862536302033%
# Accuracy @ 3.0 = 82.76863504356244%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1041
# Accuracy @ 0.0 = 98.4630163304515%
# Accuracy @ 1.0 = 97.11815561959655%
# Accuracy @ 2.5 = 89.62536023054754%
# Accuracy @ 3.0 = 82.70893371757924%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1049
# Accuracy @ 0.0 = 98.4747378455672%
# Accuracy @ 1.0 = 97.14013346043852%
# Accuracy @ 2.5 = 89.60915157292659%
# Accuracy @ 3.0 = 82.65014299332698%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1057
# Accuracy @ 0.0 = 98.48628192999054%
# Accuracy @ 1.0 = 97.16177861873227%
# Accuracy @ 2.5 = 89.59318826868495%
# Accuracy @ 3.0 = 82.5922421948912%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1065
# Accuracy @ 0.0 = 98.49765258215962%
# Accuracy @ 1.0 = 97.08920187793427%
# Accuracy @ 2.5 = 89.5774647887324%
# Accuracy @ 3.0 = 82.62910798122066%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1073
# Accuracy @ 0.0 = 98.50885368126747%
# Accuracy @ 1.0 = 97.11090400745573%
# Accuracy @ 2.5 = 89.46877912395153%
# Accuracy @ 3.0 = 82.47903075489282%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1081
# Accuracy @ 0.0 = 98.51988899167438%
# Accuracy @ 1.0 = 97.1322849213691%
# Accuracy @ 2.5 = 89.54671600370028%
# Accuracy @ 3.0 = 82.42368177613321%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1089
# Accuracy @ 0.0 = 98.5307621671258%
# Accuracy @ 1.0 = 97.15335169880625%
# Accuracy @ 2.5 = 89.62350780532599%
# Accuracy @ 3.0 = 82.46097337006428%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1097
# Accuracy @ 0.0 = 98.54147675478579%
# Accuracy @ 1.0 = 97.17411121239745%
# Accuracy @ 2.5 = 89.60802187784867%
# Accuracy @ 3.0 = 82.49772105742935%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1105
# Accuracy @ 0.0 = 98.55203619909503%
# Accuracy @ 1.0 = 97.1945701357466%
# Accuracy @ 2.5 = 89.68325791855204%
# Accuracy @ 3.0 = 82.62443438914026%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1113
# Accuracy @ 0.0 = 98.56244384546271%
# Accuracy @ 1.0 = 97.214734950584%
# Accuracy @ 2.5 = 89.66756513926325%
# Accuracy @ 3.0 = 82.56963162623539%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1121
# Accuracy @ 0.0 = 98.57270294380018%
# Accuracy @ 1.0 = 97.23461195361284%
# Accuracy @ 2.5 = 89.74130240856378%
# Accuracy @ 3.0 = 82.69402319357717%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1129
# Accuracy @ 0.0 = 98.58281665190434%
# Accuracy @ 1.0 = 97.16563330380869%
# Accuracy @ 2.5 = 89.5482728077945%
# Accuracy @ 3.0 = 82.46235606731621%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1137
# Accuracy @ 0.0 = 98.59278803869833%
# Accuracy @ 1.0 = 97.18557607739666%
# Accuracy @ 2.5 = 89.62181178540017%
# Accuracy @ 3.0 = 82.49780123131046%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1145
# Accuracy @ 0.0 = 98.60262008733625%
# Accuracy @ 1.0 = 97.2052401746725%
# Accuracy @ 2.5 = 89.60698689956332%
# Accuracy @ 3.0 = 82.53275109170306%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1153
# Accuracy @ 0.0 = 98.61231569817866%
# Accuracy @ 1.0 = 97.22463139635732%
# Accuracy @ 2.5 = 89.67909800520381%
# Accuracy @ 3.0 = 82.6539462272333%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1161
# Accuracy @ 0.0 = 98.62187769164514%
# Accuracy @ 1.0 = 97.24375538329026%
# Accuracy @ 2.5 = 89.75021533161069%
# Accuracy @ 3.0 = 82.68733850129199%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1169
# Accuracy @ 0.0 = 98.63130881094952%
# Accuracy @ 1.0 = 97.26261762189907%
# Accuracy @ 2.5 = 89.82035928143712%
# Accuracy @ 3.0 = 82.72027373823782%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1177
# Accuracy @ 0.0 = 98.64061172472387%
# Accuracy @ 1.0 = 97.28122344944775%
# Accuracy @ 2.5 = 89.88954970263381%
# Accuracy @ 3.0 = 82.75276125743416%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1185
# Accuracy @ 0.0 = 98.64978902953587%
# Accuracy @ 1.0 = 97.21518987341771%
# Accuracy @ 2.5 = 89.78902953586498%
# Accuracy @ 3.0 = 82.61603375527426%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1193
# Accuracy @ 0.0 = 98.65884325230512%
# Accuracy @ 1.0 = 97.2338642078793%
# Accuracy @ 2.5 = 89.77367979882649%
# Accuracy @ 3.0 = 82.6487845766974%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1201
# Accuracy @ 0.0 = 98.66777685262281%
# Accuracy @ 1.0 = 97.16902581182349%
# Accuracy @ 2.5 = 89.6752706078268%
# Accuracy @ 3.0 = 82.51457119067443%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1209
# Accuracy @ 0.0 = 98.67659222497932%
# Accuracy @ 1.0 = 97.18775847808105%
# Accuracy @ 2.5 = 89.66087675765095%
# Accuracy @ 3.0 = 82.5475599669148%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1217
# Accuracy @ 0.0 = 98.68529170090386%
# Accuracy @ 1.0 = 97.20624486442071%
# Accuracy @ 2.5 = 89.5645028759244%
# Accuracy @ 3.0 = 82.49794576828266%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1225
# Accuracy @ 0.0 = 98.6938775510204%
# Accuracy @ 1.0 = 97.22448979591837%
# Accuracy @ 2.5 = 89.55102040816327%
# Accuracy @ 3.0 = 82.44897959183673%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1233
# Accuracy @ 0.0 = 98.54014598540147%
# Accuracy @ 1.0 = 97.08029197080292%
# Accuracy @ 2.5 = 89.4566098945661%
# Accuracy @ 3.0 = 82.40064882400648%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1241
# Accuracy @ 0.0 = 98.54955680902499%
# Accuracy @ 1.0 = 97.09911361804996%
# Accuracy @ 2.5 = 89.44399677679291%
# Accuracy @ 3.0 = 82.35294117647058%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1249
# Accuracy @ 0.0 = 98.55884707766212%
# Accuracy @ 1.0 = 96.95756605284227%
# Accuracy @ 2.5 = 89.27141713370696%
# Accuracy @ 3.0 = 82.2257806244996%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1257
# Accuracy @ 0.0 = 98.56801909307876%
# Accuracy @ 1.0 = 96.97692919649961%
# Accuracy @ 2.5 = 89.33969769291966%
# Accuracy @ 3.0 = 82.2593476531424%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1265
# Accuracy @ 0.0 = 98.57707509881422%
# Accuracy @ 1.0 = 96.91699604743083%
# Accuracy @ 2.5 = 89.32806324110672%
# Accuracy @ 3.0 = 82.21343873517787%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1273
# Accuracy @ 0.0 = 98.586017282011%
# Accuracy @ 1.0 = 96.9363707776905%
# Accuracy @ 2.5 = 89.31657501963865%
# Accuracy @ 3.0 = 82.24666142969363%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1281
# Accuracy @ 0.0 = 98.59484777517564%
# Accuracy @ 1.0 = 96.95550351288055%
# Accuracy @ 2.5 = 89.38329430132708%
# Accuracy @ 3.0 = 82.35753317720531%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1289
# Accuracy @ 0.0 = 98.60356865787432%
# Accuracy @ 1.0 = 96.9743987587277%
# Accuracy @ 2.5 = 89.44918541505042%
# Accuracy @ 3.0 = 82.46702870442203%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1297
# Accuracy @ 0.0 = 98.61218195836547%
# Accuracy @ 1.0 = 96.9159599074788%
# Accuracy @ 2.5 = 89.36006168080185%
# Accuracy @ 3.0 = 82.26676946800309%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1305
# Accuracy @ 0.0 = 98.62068965517241%
# Accuracy @ 1.0 = 96.85823754789273%
# Accuracy @ 2.5 = 89.34865900383141%
# Accuracy @ 3.0 = 82.22222222222221%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1313
# Accuracy @ 0.0 = 98.62909367859864%
# Accuracy @ 1.0 = 96.87738004569688%
# Accuracy @ 2.5 = 89.33739527798934%
# Accuracy @ 3.0 = 82.25437928408226%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1321
# Accuracy @ 0.0 = 98.56169568508706%
# Accuracy @ 1.0 = 96.82059046177139%
# Accuracy @ 2.5 = 89.25056775170326%
# Accuracy @ 3.0 = 82.21044663133989%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1329
# Accuracy @ 0.0 = 98.57035364936041%
# Accuracy @ 1.0 = 96.83972911963883%
# Accuracy @ 2.5 = 89.31527464258842%
# Accuracy @ 3.0 = 82.24228743416103%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1337
# Accuracy @ 0.0 = 98.57890800299177%
# Accuracy @ 1.0 = 96.8586387434555%
# Accuracy @ 2.5 = 89.37920718025431%
# Accuracy @ 3.0 = 82.19895287958116%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1345
# Accuracy @ 0.0 = 98.58736059479554%
# Accuracy @ 1.0 = 96.87732342007435%
# Accuracy @ 2.5 = 89.29368029739777%
# Accuracy @ 3.0 = 82.00743494423793%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1353
# Accuracy @ 0.0 = 98.59571322985957%
# Accuracy @ 1.0 = 96.89578713968959%
# Accuracy @ 2.5 = 89.3569844789357%
# Accuracy @ 3.0 = 82.039911308204%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1361
# Accuracy @ 0.0 = 98.60396767083027%
# Accuracy @ 1.0 = 96.91403379867745%
# Accuracy @ 2.5 = 89.3460690668626%
# Accuracy @ 3.0 = 81.92505510653932%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1369
# Accuracy @ 0.0 = 98.61212563915267%
# Accuracy @ 1.0 = 96.93206720233746%
# Accuracy @ 2.5 = 89.33528122717313%
# Accuracy @ 3.0 = 81.8845872899927%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1377
# Accuracy @ 0.0 = 98.62018881626724%
# Accuracy @ 1.0 = 96.94989106753813%
# Accuracy @ 2.5 = 89.39724037763254%
# Accuracy @ 3.0 = 81.98983297022512%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1385
# Accuracy @ 0.0 = 98.62815884476535%
# Accuracy @ 1.0 = 96.89530685920577%
# Accuracy @ 2.5 = 89.38628158844766%
# Accuracy @ 3.0 = 82.0216606498195%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1393
# Accuracy @ 0.0 = 98.63603732950466%
# Accuracy @ 1.0 = 96.91313711414213%
# Accuracy @ 2.5 = 89.44723618090453%
# Accuracy @ 3.0 = 82.05312275664033%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1401
# Accuracy @ 0.0 = 98.64382583868665%
# Accuracy @ 1.0 = 96.85938615274804%
# Accuracy @ 2.5 = 89.22198429693077%
# Accuracy @ 3.0 = 81.79871520342613%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1409
# Accuracy @ 0.0 = 98.65152590489708%
# Accuracy @ 1.0 = 96.87721788502483%
# Accuracy @ 2.5 = 89.14123491838183%
# Accuracy @ 3.0 = 81.76011355571327%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1417
# Accuracy @ 0.0 = 98.6591390261115%
# Accuracy @ 1.0 = 96.8242766407904%
# Accuracy @ 2.5 = 89.13196894848271%
# Accuracy @ 3.0 = 81.58080451658434%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1425
# Accuracy @ 0.0 = 98.66666666666667%
# Accuracy @ 1.0 = 96.84210526315789%
# Accuracy @ 2.5 = 89.19298245614034%
# Accuracy @ 3.0 = 81.6842105263158%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1433
# Accuracy @ 0.0 = 98.67411025819958%
# Accuracy @ 1.0 = 96.85973482205164%
# Accuracy @ 2.5 = 89.11374738311235%
# Accuracy @ 3.0 = 81.5771109560363%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1441
# Accuracy @ 0.0 = 98.68147120055517%
# ...
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1593
# Accuracy @ 0.0 = 98.80728185812931%
# Accuracy @ 1.0 = 96.98681732580037%
# Accuracy @ 2.5 = 88.95166352793471%
# Accuracy @ 3.0 = 81.10483364720653%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1601
# Accuracy @ 0.0 = 98.81324172392254%
# Accuracy @ 1.0 = 97.00187382885697%
# Accuracy @ 2.5 = 88.88194878201125%
# Accuracy @ 3.0 = 80.94940662086196%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1609
# Accuracy @ 0.0 = 98.81914232442512%
# Accuracy @ 1.0 = 97.01678060907396%
# Accuracy @ 2.5 = 88.9372280919826%
# Accuracy @ 3.0 = 80.98197638284648%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1617
# Accuracy @ 0.0 = 98.82498453927026%
# Accuracy @ 1.0 = 97.03153988868274%
# Accuracy @ 2.5 = 88.93011750154606%
# Accuracy @ 3.0 = 80.95238095238095%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1625
# Accuracy @ 0.0 = 98.83076923076923%
# Accuracy @ 1.0 = 97.04615384615384%
# Accuracy @ 2.5 = 88.98461538461538%
# Accuracy @ 3.0 = 80.92307692307692%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1633
# Accuracy @ 0.0 = 98.83649724433558%
# Accuracy @ 1.0 = 97.06062461726883%
# Accuracy @ 2.5 = 88.97734231475812%
# Accuracy @ 3.0 = 80.95529699938763%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1641
# Accuracy @ 0.0 = 98.84216940889702%
# Accuracy @ 1.0 = 97.07495429616088%
# Accuracy @ 2.5 = 88.97014015843997%
# Accuracy @ 3.0 = 80.9262644728824%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1649
# Accuracy @ 0.0 = 98.84778653729533%
# Accuracy @ 1.0 = 97.08914493632504%
# Accuracy @ 2.5 = 89.02365069739236%
# Accuracy @ 3.0 = 81.01879927228623%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1657
# Accuracy @ 0.0 = 98.85334942667471%
# Accuracy @ 1.0 = 97.10319855159928%
# Accuracy @ 2.5 = 89.07664453832227%
# Accuracy @ 3.0 = 81.05009052504526%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1665
# Accuracy @ 0.0 = 98.85885885885885%
# Accuracy @ 1.0 = 97.11711711711712%
# Accuracy @ 2.5 = 89.12912912912913%
# Accuracy @ 3.0 = 81.14114114114113%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1673
# Accuracy @ 0.0 = 98.86431560071728%
# Accuracy @ 1.0 = 97.13090257023312%
# Accuracy @ 2.5 = 89.06156604901375%
# Accuracy @ 3.0 = 81.11177525403467%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1681
# Accuracy @ 0.0 = 98.86972040452112%
# Accuracy @ 1.0 = 97.14455681142177%
# Accuracy @ 2.5 = 88.93515764425936%
# Accuracy @ 3.0 = 81.0232004759072%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1689
# Accuracy @ 0.0 = 98.81586737714623%
# Accuracy @ 1.0 = 97.09887507400829%
# Accuracy @ 2.5 = 88.92835997631735%
# Accuracy @ 3.0 = 81.05387803433985%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1697
# Accuracy @ 0.0 = 98.82144961697112%
# Accuracy @ 1.0 = 97.05362404242781%
# Accuracy @ 2.5 = 88.92162639952858%
# Accuracy @ 3.0 = 80.96641131408367%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1705
# Accuracy @ 0.0 = 98.82697947214076%
# Accuracy @ 1.0 = 97.0674486803519%
# Accuracy @ 2.5 = 88.85630498533725%
# Accuracy @ 3.0 = 80.93841642228739%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1713
# Accuracy @ 0.0 = 98.83245767659078%
# Accuracy @ 1.0 = 97.08114419147694%
# Accuracy @ 2.5 = 88.84997081144192%
# Accuracy @ 3.0 = 80.96906012842966%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1721
# Accuracy @ 0.0 = 98.83788495061012%
# Accuracy @ 1.0 = 97.09471237652527%
# Accuracy @ 2.5 = 88.78558977338756%
# Accuracy @ 3.0 = 80.94131319000581%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1729
# Accuracy @ 0.0 = 98.84326200115675%
# Accuracy @ 1.0 = 97.10815500289185%
# Accuracy @ 2.5 = 88.66396761133603%
# Accuracy @ 3.0 = 80.85598611914402%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1737
# Accuracy @ 0.0 = 98.84858952216466%
# Accuracy @ 1.0 = 97.12147380541163%
# Accuracy @ 2.5 = 88.71617731721358%
# Accuracy @ 3.0 = 80.94415659182499%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1745
# Accuracy @ 0.0 = 98.8538681948424%
# Accuracy @ 1.0 = 97.07736389684814%
# Accuracy @ 2.5 = 88.71060171919771%
# Accuracy @ 3.0 = 80.91690544412607%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1753
# Accuracy @ 0.0 = 98.85909868796348%
# Accuracy @ 1.0 = 97.0907016543069%
# Accuracy @ 2.5 = 88.76212207644039%
# Accuracy @ 3.0 = 80.9469480889903%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1761
# Accuracy @ 0.0 = 98.86428165814878%
# Accuracy @ 1.0 = 97.10391822827938%
# Accuracy @ 2.5 = 88.81317433276547%
# Accuracy @ 3.0 = 81.0335036910846%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1769
# Accuracy @ 0.0 = 98.86941775014132%
# Accuracy @ 1.0 = 97.11701526286038%
# Accuracy @ 2.5 = 88.86376483889204%
# Accuracy @ 3.0 = 81.11927642736009%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1777
# Accuracy @ 0.0 = 98.87450759707373%
# Accuracy @ 1.0 = 97.129994372538%
# Accuracy @ 2.5 = 88.85762521102983%
# Accuracy @ 3.0 = 81.09172763083849%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1785
# Accuracy @ 0.0 = 98.8795518207283%
# Accuracy @ 1.0 = 97.14285714285714%
# Accuracy @ 2.5 = 88.8515406162465%
# Accuracy @ 3.0 = 81.1204481792717%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1793
# Accuracy @ 0.0 = 98.8287785833798%
# Accuracy @ 1.0 = 97.09983268265476%
# Accuracy @ 2.5 = 88.84551031790295%
# Accuracy @ 3.0 = 81.14891243725599%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1801
# Accuracy @ 0.0 = 98.83398112159911%
# Accuracy @ 1.0 = 97.11271515824542%
# Accuracy @ 2.5 = 88.89505830094392%
# Accuracy @ 3.0 = 81.23264852859522%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1809
# Accuracy @ 0.0 = 98.8391376451078%
# Accuracy @ 1.0 = 97.12548369264788%
# Accuracy @ 2.5 = 88.94416804864565%
# Accuracy @ 3.0 = 81.31564400221116%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1817
# Accuracy @ 0.0 = 98.8442487616951%
# Accuracy @ 1.0 = 97.13813979086406%
# Accuracy @ 2.5 = 88.93780957622455%
# Accuracy @ 3.0 = 81.23280132085856%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1825
# Accuracy @ 0.0 = 98.84931506849315%
# Accuracy @ 1.0 = 97.15068493150685%
# Accuracy @ 2.5 = 88.93150684931507%
# Accuracy @ 3.0 = 81.2054794520548%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1833
# Accuracy @ 0.0 = 98.8543371522095%
# Accuracy @ 1.0 = 97.16312056737588%
# Accuracy @ 2.5 = 88.9798145117294%
# Accuracy @ 3.0 = 81.2329514457174%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1841
# Accuracy @ 0.0 = 98.85931558935361%
# Accuracy @ 1.0 = 97.17544812601847%
# Accuracy @ 2.5 = 89.02770233568714%
# Accuracy @ 3.0 = 81.31450298750678%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1849
# Accuracy @ 0.0 = 98.86425094645755%
# Accuracy @ 1.0 = 97.18766901027583%
# Accuracy @ 2.5 = 89.07517577068685%
# Accuracy @ 3.0 = 81.34126554894537%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1857
# Accuracy @ 0.0 = 98.86914378029078%
# Accuracy @ 1.0 = 97.1997845988153%
# Accuracy @ 2.5 = 89.01453957996769%
# Accuracy @ 3.0 = 81.31394722670974%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1865
# Accuracy @ 0.0 = 98.8739946380697%
# Accuracy @ 1.0 = 97.2117962466488%
# Accuracy @ 2.5 = 89.06166219839142%
# Accuracy @ 3.0 = 81.3941018766756%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1873
# Accuracy @ 0.0 = 98.87880405766151%
# Accuracy @ 1.0 = 97.22370528563802%
# Accuracy @ 2.5 = 89.05499199145756%
# Accuracy @ 3.0 = 81.42018152696208%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1881
# Accuracy @ 0.0 = 98.88357256778309%
# Accuracy @ 1.0 = 97.18234981392875%
# Accuracy @ 2.5 = 88.99521531100478%
# Accuracy @ 3.0 = 81.39287612971825%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1889
# Accuracy @ 0.0 = 98.8883006881948%
# Accuracy @ 1.0 = 97.19428268925357%
# Accuracy @ 2.5 = 89.04182106934886%
# Accuracy @ 3.0 = 81.36580201164637%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1897
# Accuracy @ 0.0 = 98.8929889298893%
# Accuracy @ 1.0 = 97.20611491829204%
# Accuracy @ 2.5 = 89.08803373748023%
# Accuracy @ 3.0 = 81.44438587243016%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1905
# Accuracy @ 0.0 = 98.84514435695539%
# Accuracy @ 1.0 = 97.16535433070867%
# Accuracy @ 2.5 = 89.08136482939632%
# Accuracy @ 3.0 = 81.36482939632546%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1913
# Accuracy @ 0.0 = 98.84997386304234%
# Accuracy @ 1.0 = 97.17720857292211%
# Accuracy @ 2.5 = 89.07475169890225%
# Accuracy @ 3.0 = 81.39048614741245%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1921
# Accuracy @ 0.0 = 98.85476314419573%
# Accuracy @ 1.0 = 97.1889640812077%
# Accuracy @ 2.5 = 89.12024986985945%
# Accuracy @ 3.0 = 81.41592920353983%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1929
# Accuracy @ 0.0 = 98.85951270088128%
# Accuracy @ 1.0 = 97.20062208398133%
# Accuracy @ 2.5 = 89.11353032659409%
# Accuracy @ 3.0 = 81.44116122343183%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1937
# Accuracy @ 0.0 = 98.86422302529685%
# Accuracy @ 1.0 = 97.21218378936499%
# Accuracy @ 2.5 = 89.1584925141972%
# Accuracy @ 3.0 = 81.51781104801239%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1945
# Accuracy @ 0.0 = 98.86889460154241%
# Accuracy @ 1.0 = 97.22365038560412%
# Accuracy @ 2.5 = 89.15167095115682%
# Accuracy @ 3.0 = 81.54241645244215%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1953
# Accuracy @ 0.0 = 98.87352790578598%
# Accuracy @ 1.0 = 97.23502304147466%
# Accuracy @ 2.5 = 89.19610855094726%
# Accuracy @ 3.0 = 81.46441372247824%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1961
# Accuracy @ 0.0 = 98.87812340642529%
# Accuracy @ 1.0 = 97.24630290668026%
# Accuracy @ 2.5 = 89.1891891891892%
# Accuracy @ 3.0 = 81.48903620601735%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1969
# Accuracy @ 0.0 = 98.88268156424581%
# Accuracy @ 1.0 = 97.25749111223972%
# Accuracy @ 2.5 = 89.18232605383444%
# Accuracy @ 3.0 = 81.46267140680548%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1977
# Accuracy @ 0.0 = 98.8872028325746%
# Accuracy @ 1.0 = 97.26858877086495%
# Accuracy @ 2.5 = 89.12493677288822%
# Accuracy @ 3.0 = 81.43651997976733%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1985
# Accuracy @ 0.0 = 98.89168765743072%
# Accuracy @ 1.0 = 97.27959697732997%
# Accuracy @ 2.5 = 89.06801007556675%
# Accuracy @ 3.0 = 81.41057934508817%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 1993
# Accuracy @ 0.0 = 98.89613647767185%
# Accuracy @ 1.0 = 97.2905168088309%
# Accuracy @ 2.5 = 89.11189162067235%
# Accuracy @ 3.0 = 81.38484696437531%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2001
# Accuracy @ 0.0 = 98.90054972513744%
# Accuracy @ 1.0 = 97.30134932533733%
# Accuracy @ 2.5 = 89.15542228885556%
# Accuracy @ 3.0 = 81.30934532733633%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2009
# Accuracy @ 0.0 = 98.90492782478844%
# Accuracy @ 1.0 = 97.31209556993528%
# Accuracy @ 2.5 = 89.14883026381284%
# Accuracy @ 3.0 = 81.33399701343951%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2017
# Accuracy @ 0.0 = 98.90927119484383%
# Accuracy @ 1.0 = 97.32275656916212%
# Accuracy @ 2.5 = 89.19186911254337%
# Accuracy @ 3.0 = 81.40803173029252%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2025
# Accuracy @ 0.0 = 98.91358024691358%
# Accuracy @ 1.0 = 97.33333333333334%
# Accuracy @ 2.5 = 89.13580246913581%
# Accuracy @ 3.0 = 81.33333333333333%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2033
# Accuracy @ 0.0 = 98.91785538612888%
# Accuracy @ 1.0 = 97.34382685686178%
# Accuracy @ 2.5 = 89.08017707820954%
# Accuracy @ 3.0 = 81.30841121495327%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2041
# Accuracy @ 0.0 = 98.92209701126899%
# Accuracy @ 1.0 = 97.30524252817247%
# Accuracy @ 2.5 = 89.0249877511024%
# Accuracy @ 3.0 = 81.23468887800098%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2049
# Accuracy @ 0.0 = 98.92630551488531%
# Accuracy @ 1.0 = 97.31576378721327%
# Accuracy @ 2.5 = 89.0190336749634%
# Accuracy @ 3.0 = 81.16154221571499%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%
# Iteration 2057
# Accuracy @ 0.0 = 98.93048128342245%
# Accuracy @ 1.0 = 97.32620320855615%
# Accuracy @ 2.5 = 88.91589693728731%
# Accuracy @ 3.0 = 81.04035002430724%
# Accuracy @ 3.5 = 0.0%
# Accuracy @ 4.0 = 0.0%
# Accuracy @ 4.5 = 0.0%
# Accuracy @ 5.0 = 0.0%
# Accuracy @ 10.0 = 0.0%

# %%
len(mnist_test_dataset)
# Out:
# 10000
